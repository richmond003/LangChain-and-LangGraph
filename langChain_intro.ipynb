# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from rich import print

# %%
load_dotenv()
openai_key = os.getenv("OPENAI_API_KEY")

# %%
llm = OpenAI(
    temperature=0.7,
    api_key= openai_key,
    base_url="https://api.groq.com/openai/v1"
)

# %%
prompt = "Suggest me a skill that is in demand"
response = llm.invoke(prompt)
print(f"Suggested Skill: \n{response}")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 2
#       1 prompt = "Suggest me a skill that is in demand"
# ----> 2 response = llm.invoke(prompt)
#       3 print(f"Suggested Skill: \n{response}")
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\langchain_core\language_models\llms.py:381, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     370 @override
#     371 def invoke(
#     372     self,
#    (...)    377     **kwargs: Any,
#     378 ) -> str:
#     379     config = ensure_config(config)
#     380     return (
# --> 381         self.generate_prompt(
#     382             [self._convert_input(input)],
#     383             stop=stop,
#     384             callbacks=config.get("callbacks"),
#     385             tags=config.get("tags"),
#     386             metadata=config.get("metadata"),
#     387             run_name=config.get("run_name"),
#     388             run_id=config.pop("run_id", None),
#     389             **kwargs,
#     390         )
#     391         .generations[0][0]
#     392         .text
#     393     )
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\langchain_core\language_models\llms.py:798, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     789 @override
#     790 def generate_prompt(
#     791     self,
#    (...)    795     **kwargs: Any,
#     796 ) -> LLMResult:
#     797     prompt_strings = [p.to_string() for p in prompts]
# --> 798     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1028, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1009 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1010     run_managers = [
#    1011         callback_manager.on_llm_start(
#    1012             self._serialized,
#    (...)   1026         )
#    1027     ]
# -> 1028     return self._generate_helper(
#    1029         prompts,
#    1030         stop,
#    1031         run_managers,
#    1032         new_arg_supported=bool(new_arg_supported),
#    1033         **kwargs,
#    1034     )
#    1035 if len(missing_prompts) > 0:
#    1036     run_managers = [
#    1037         callback_managers[idx].on_llm_start(
#    1038             self._serialized,
#    (...)   1045         for idx in missing_prompt_idxs
#    1046     ]
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\langchain_core\language_models\llms.py:824, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     813 def _generate_helper(
#     814     self,
#     815     prompts: list[str],
#    (...)    820     **kwargs: Any,
#     821 ) -> LLMResult:
#     822     try:
#     823         output = (
# --> 824             self._generate(
#     825                 prompts,
#     826                 stop=stop,
#     827                 # TODO: support multiple run managers
#     828                 run_manager=run_managers[0] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831             if new_arg_supported
#     832             else self._generate(prompts, stop=stop)
#     833         )
#     834     except BaseException as e:
#     835         for run_manager in run_managers:
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\langchain_openai\llms\base.py:492, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     476     choices.append(
#     477         {
#     478             "text": generation.text,
#    (...)    489         }
#     490     )
#     491 else:
# --> 492     response = self.client.create(prompt=_prompts, **params)
#     493     if not isinstance(response, dict):
#     494         # V1 client returns the response in an PyDantic object instead of
#     495         # dict. For the transition period, we deep convert it to dict.
#     496         response = response.model_dump()
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\openai\resources\completions.py:554, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     525 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     526 def create(
#     527     self,
#    (...)    552     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     553 ) -> Completion | Stream[Completion]:
# --> 554     return self._post(
#     555         "/completions",
#     556         body=maybe_transform(
#     557             {
#     558                 "model": model,
#     559                 "prompt": prompt,
#     560                 "best_of": best_of,
#     561                 "echo": echo,
#     562                 "frequency_penalty": frequency_penalty,
#     563                 "logit_bias": logit_bias,
#     564                 "logprobs": logprobs,
#     565                 "max_tokens": max_tokens,
#     566                 "n": n,
#     567                 "presence_penalty": presence_penalty,
#     568                 "seed": seed,
#     569                 "stop": stop,
#     570                 "stream": stream,
#     571                 "stream_options": stream_options,
#     572                 "suffix": suffix,
#     573                 "temperature": temperature,
#     574                 "top_p": top_p,
#     575                 "user": user,
#     576             },
#     577             completion_create_params.CompletionCreateParamsStreaming
#     578             if stream
#     579             else completion_create_params.CompletionCreateParamsNonStreaming,
#     580         ),
#     581         options=make_request_options(
#     582             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     583         ),
#     584         cast_to=Completion,
#     585         stream=stream or False,
#     586         stream_cls=Stream[Completion],
#     587     )
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\richm\OneDrive\Desktop\AI Engineering\LangChain & LangGraph\.venv\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'Unknown request URL: POST /openai/v1/completions. Please check the URL for typos, or see the docs at https://console.groq.com/docs/', 'type': 'invalid_request_error', 'code': 'unknown_url'}}
